# %%
import IPython.display as ipd

# %%
ipd.Audio("C:/Users/Yash Ramani/Nature sounds recognition/UrbanSound8K/audio/fold1/9031-3-2-0.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import IPython.display as ipd
import librosa
import librosa.display
import matplotlib.pyplot as plt

# %%
filename = "C:/Users/Yash Ramani/Nature sounds recognition/UrbanSound8K/audio/fold1/21684-9-0-39.wav"
plt.figure(figsize=(12,4))
data,sample_rate = librosa.load(filename)
_ = librosa.display.waveplot(data,sr=sample_rate)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import pandas as pd
import os
import librosa
import librosa.display

# %%
from helpers.wavfilehelper import WavFileHelper

# %%
wavfilehelper = WavFileHelper()

# %%
audiodata = []
metadata = pd.read_csv("C:/Users/Yash Ramani/Nature sounds recognition/UrbanSound8K/metadata/UrbanSound8K.csv")
metadata.head()
for index,row in metadata.iterrows():
    file_name = os.path.join(os.path.abspath("C:/Users/Yash Ramani/Nature sounds recognition/UrbanSound8K/audio"),'fold'+str(row["fold"])+'/', str(row["slice_file_name"]))
    data = wavfilehelper.read_file_properties(file_name)
    audiodata.append(data)
audiodf = pd.DataFrame(audiodata, columns=['num_channels', 'sample_rate', 'bit_depth'])

# %%
print(audiodf.num_channels.value_counts(normalize=True))
# Out:
# 2    0.915369
# 1    0.084631
# Name: num_channels, dtype: float64

# %%
print(audiodf.sample_rate.value_counts(normalize=True))
# Out:
# 44100     0.614979
# 48000     0.286532
# 96000     0.069858
# 24000     0.009391
# 16000     0.005153
# 22050     0.005039
# 11025     0.004466
# 192000    0.001947
# 8000      0.001374
# 11024     0.000802
# 32000     0.000458
# Name: sample_rate, dtype: float64

# %%
print(audiodf.bit_depth.value_counts(normalize=True))
# Out:
# 16    0.659414
# 24    0.315277
# 32    0.019354
# 8     0.004924
# 4     0.001031
# Name: bit_depth, dtype: float64
